# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from math import sin, radians

def move_upwind(wind_angle, boat_angle):
    #delta = abs(wind_angle - boat_angle)
    delta = wind_angle - boat_angle
    
    #if delta>180:
    #    delta = 180 - (delta - 180)
    
    delta = sin(radians(delta))
    return delta

a = np.linspace(0,360,360)

def f(x, n):
    return x*n

vfunc = np.vectorize(move_upwind)
b = vfunc(50, a)

plt.plot(a, b)
#move_upwind(0, 190)

# %%
math.sin(math.radians(90))
# Out:
# 1.0
