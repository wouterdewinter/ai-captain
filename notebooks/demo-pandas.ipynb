# %%
# %matplotlib inline

# importing pandas and numpy
import pandas as pd
import numpy as np

import os

# %% [markdown]
# # about CSV

# %%
# read a CSV into a dataframe
df = pd.read_csv(os.path.join('..', 'data', 'datasets', 'kc_house_data.csv'))

# %%
# show shape
df.shape
# Out:
# (21613, 21)

# %%
# show the first couple of rows (default is 5 rows)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %%
# show the last couple of rows (default is 5 rows)
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 21608         1530      1131     3.0           0     0     ...          8
# 21609         2310      5813     2.0           0     0     ...          8
# 21610         1020      1350     2.0           0     0     ...          7
# 21611         1600      2388     2.0           0     0     ...          8
# 21612         1020      1076     2.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
# show columns (in a list)
list(df)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
# selecting a column
df['bathrooms'] # or df.bathrooms
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
# 5        4.50
# 6        2.25
# 7        1.50
# 8        1.00
# 9        2.50
# 10       2.50
# 11       1.00
# 12       1.00
# 13       1.75
# 14       2.00
# 15       3.00
# 16       2.00
# 17       1.00
# 18       1.00
# 19       1.00
# 20       1.75
# 21       2.75
# 22       2.50
# 23       1.50
# 24       2.25
# 25       2.00
# 26       1.75
# 27       1.00
# 28       1.75
# 29       2.50
#          ...
# 21583    1.00
# 21584    2.50
# 21585    2.50
# 21586    2.50
# 21587    2.50
# 21588    1.50
# 21589    2.50
# 21590    3.50
# 21591    2.75
# 21592    2.25
# 21593    3.75
# 21594    2.75
# 21595    2.25
# 21596    2.75
# 21597    3.25
# 21598    2.50
# 21599    3.00
# 21600    3.75
# 21601    2.50
# 21602    1.75
# 21603    2.50
# 21604    2.00
# 21605    2.50
# 21606    3.50
# 21607    2.50
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: bathrooms, Length: 21613, dtype: float64

# %%
# selecting data by row numbers (.iloc)
df.iloc[5:10]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 5    101930     1.0           0     0     ...         11        3890
# 6      6819     2.0           0     0     ...          7        1715
# 7      9711     1.0           0     0     ...          7        1060
# 8      7470     1.0           0     0     ...          7        1050
# 9      6560     2.0           0     0     ...          7        1890
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 5           1530      2001             0    98053  47.6561 -122.005
# 6              0      1995             0    98003  47.3097 -122.327
# 7              0      1963             0    98198  47.4095 -122.315
# 8            730      1960             0    98146  47.5123 -122.337
# 9              0      2003             0    98038  47.3684 -122.031
#
#    sqft_living15  sqft_lot15
# 5           4760      101930
# 6           2238        6819
# 7           1650        9711
# 8           1780        8113
# 9           2390        7570
#
# [5 rows x 21 columns]

# %%
# selecting the values for bedrooms from the rows shown above
df.iloc[5:10]['bedrooms'] # or df['bedrooms'][5:10]
# Out:
# 5    4
# 6    3
# 7    3
# 8    3
# 9    3
# Name: bedrooms, dtype: int64

# %%
# Selecting data by label or by a conditional statment (.loc)
df.loc[df.bedrooms > 10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11       3.00
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 8757          3000      4960     2.0           0     0     ...          7
# 15870         1620      6000     1.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 8757  -122.363           1420        4960
# 15870 -122.331           1330        4700
#
# [2 rows x 21 columns]

# %%
# getting the maximum of a column
df['sqft_living'].max()   # or df.sqft_living.max()
# Out:
# 13540

# %%
# getting the minimum of a comumn
df['sqft_living'].min()   # or df.sqft_living.min()
# Out:
# 290

# %%
# Clip sqft_living to 10000; i.e. set sqft_living > 10000 to 10000, using mask
df["sqft_living"] = df["sqft_living"].mask(df["sqft_living"] > 10000, 10000)
df['sqft_living'].max()

# %%
# create dataframe from series
a = pd.Series([1, 2, 3, np.nan, np.nan, 4, 5])
b = pd.Series(['dsads', 'dsda', np.nan, 'dsad', 'dsad', 'dasda', 'dsda'])
df1 = pd.DataFrame({'a': a, 'b': b})
df1
# Out:
#      a      b
# 0  1.0  dsads
# 1  2.0   dsda
# 2  3.0    NaN
# 3  NaN   dsad
# 4  NaN   dsad
# 5  4.0  dasda
# 6  5.0   dsda

# %%
# count missing values
df1.isna().sum()
# Out:
# a    2
# b    1
# dtype: int64

# %%
# fill missing values
df1['a'].fillna(0, inplace=True)
df1['b'].fillna('nope', inplace=True)
df1
# Out:
#      a      b
# 0  1.0  dsads
# 1  2.0   dsda
# 2  3.0   nope
# 3  0.0   dsad
# 4  0.0   dsad
# 5  4.0  dasda
# 6  5.0   dsda

# %%
# create dataframe from series
a = pd.Series([1, 2, 3, np.nan, np.nan, 4, 5])
b = pd.Series(['dsads', 'dsda', np.nan, 'dsad', 'dsad', 'dasda', 'dsda'])
df_1 = pd.DataFrame({'a': a, 'b': b})
df_1
# Out:
#      a      b
# 0  1.0  dsads
# 1  2.0   dsda
# 2  3.0    NaN
# 3  NaN   dsad
# 4  NaN   dsad
# 5  4.0  dasda
# 6  5.0   dsda

# %%
# propagate last valid observation forward
df_1['a'].fillna(method='ffill', inplace=True)
df_1
# Out:
#      a      b
# 0  1.0  dsads
# 1  2.0   dsda
# 2  3.0    NaN
# 3  3.0   dsad
# 4  3.0   dsad
# 5  4.0  dasda
# 6  5.0   dsda

# %%
# Drop rows that contain missing values
df_1.dropna(inplace = True)
df_1
# Out:
#      a      b
# 0  1.0  dsads
# 1  2.0   dsda
# 3  3.0   dsad
# 4  3.0   dsad
# 5  4.0  dasda
# 6  5.0   dsda

# %%
# sorting
df.sort_values('bathrooms', ascending=False).head()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 12777  1225069038  20140505T000000  2280000.0         7       8.00
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 7252         12050     27600     2.5           0     3     ...         13
# 12777        13540    307752     3.0           0     4     ...         12
# 9254          9890     31374     2.0           0     4     ...         13
# 8546          4050      6504     2.0           0     0     ...          7
# 8092          9640     13068     1.0           1     4     ...         12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 7252         8570           3480      1910          1987    98102  47.6298
# 12777        9410           4130      1999             0    98053  47.6675
# 9254         8860           1030      2001             0    98039  47.6305
# 8546         4050              0      1996             0    98144  47.5923
# 8092         4820           4820      1983          2009    98040  47.5570
#
#           long  sqft_living15  sqft_lot15
# 7252  -122.323           3940        8800
# 12777 -121.986           4850      217800
# 9254  -122.240           4540       42730
# 8546  -122.301           1448        3866
# 8092  -122.210           3270       10454
#
# [5 rows x 21 columns]

# %%
# basic plotting
df.plot.scatter(x='sqft_living', y='sqft_above')

# %%
# groupby
df.groupby('condition').price.mean().plot(kind='bar')

# %%
# merge
df2 = pd.DataFrame([{'b': 'dsad', 'c': 22}, {'b': 'nope', 'c': 300}])
pd.merge(df1, df2, on='b', how='left').dropna()

# %%
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col0 {
#             background-color:  #023858;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col1 {
#             background-color:  #faf3f9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col2 {
#             background-color:  #eae6f1;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col3 {
#             background-color:  #e1dfed;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col4 {
#             background-color:  #e6e2ef;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col5 {
#             background-color:  #fff7fb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col6 {
#             background-color:  #d6d6e9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col7 {
#             background-color:  #faf2f8;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col8 {
#             background-color:  #f2ecf5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col9 {
#             background-color:  #d1d2e6;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col10 {
#             background-color:  #e4e1ef;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col11 {
#             background-color:  #dcdaeb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col12 {
#             background-color:  #dddbec;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col13 {
#             background-color:  #c6cce3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col14 {
#             background-color:  #e2dfee;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col15 {
#             background-color:  #adc1dd;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col16 {
#             background-color:  #ece7f2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col17 {
#             background-color:  #a7bddb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col18 {
#             background-color:  #d8d7e9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow0_col19 {
#             background-color:  #fef6fb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col0 {
#             background-color:  #efe9f3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col1 {
#             background-color:  #023858;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col2 {
#             background-color:  #9cb9d9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col3 {
#             background-color:  #3f93c2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col4 {
#             background-color:  #056faf;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col5 {
#             background-color:  #dcdaeb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col6 {
#             background-color:  #97b7d7;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col7 {
#             background-color:  #c1cae2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col8 {
#             background-color:  #8cb3d5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col9 {
#             background-color:  #c2cbe2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col10 {
#             background-color:  #1077b4;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col11 {
#             background-color:  #1e80b8;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col12 {
#             background-color:  #84b0d3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col13 {
#             background-color:  #bdc8e1;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col14 {
#             background-color:  #c4cbe3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col15 {
#             background-color:  #b7c5df;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col16 {
#             background-color:  #9ebad9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col17 {
#             background-color:  #a7bddb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col18 {
#             background-color:  #2182b9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow1_col19 {
#             background-color:  #dbdaeb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col0 {
#             background-color:  #ede7f2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col1 {
#             background-color:  #b1c2de;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col2 {
#             background-color:  #023858;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col3 {
#             background-color:  #4295c3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col4 {
#             background-color:  #2d8abd;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col5 {
#             background-color:  #e7e3f0;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col6 {
#             background-color:  #b0c2de;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col7 {
#             background-color:  #faf3f9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col8 {
#             background-color:  #e7e3f0;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col9 {
#             background-color:  #c4cbe3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col10 {
#             background-color:  #84b0d3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col11 {
#             background-color:  #4a98c5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col12 {
#             background-color:  #8cb3d5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col13 {
#             background-color:  #a5bddb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col14 {
#             background-color:  #dcdaeb;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col15 {
#             background-color:  #cccfe5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col16 {
#             background-color:  #ede7f2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col17 {
#             background-color:  #8bb2d4;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col18 {
#             background-color:  #67a4cc;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow2_col19 {
#             background-color:  #e6e2ef;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col0 {
#             background-color:  #ece7f2;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col1 {
#             background-color:  #5c9fc9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col2 {
#             background-color:  #4c99c5;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col3 {
#             background-color:  #023858;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col4 {
#             background-color:  #0568a3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col5 {
#             background-color:  #dddbec;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col6 {
#             background-color:  #4094c3;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col7 {
#             background-color:  #f0eaf4;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col8 {
#             background-color:  #d1d2e6;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col9 {
#             background-color:  #e1dfed;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col10 {
#             background-color:  #1278b4;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col11 {
#             background-color:  #056faf;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col12 {
#             background-color:  #93b5d6;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col13 {
#             background-color:  #308cbe;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col14 {
#             background-color:  #d6d6e9;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784f4380b59arow3_col15 {
#             background-color:  #d5d5e8;
#         }    #T_c01fd60a_e8bc_11e8_bb12_784
